# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import numpy as np

# %%
import pandas as pd

# %%
x=pd.read_csv("https://raw.githubusercontent.com/H16902/Data/main/Copy%20of%20Global_Superstore2.csv")
x.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891  31-07-2012  31-07-2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  05-02-2013  07-02-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  17-10-2013  18-10-2013   First Class    CR-12730
# 3   13524  ES-2013-1579342  28-01-2013  30-01-2013   First Class    KM-16375
# 4   47221     SG-2013-4320  05-11-2013  06-11-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
geet=x
y=pd.DatetimeIndex(geet['Order Date']).year.unique()
y
# Out:
# Index([2012, 2013, 2011, 2014], dtype='int32', name='Order Date')

# %%
furniture=geet[geet["Category"]=="Furniture"]
furniture.describe()
# Out:
#              Row ID   Postal Code        Sales     Quantity     Discount  \
# count   9876.000000   2121.000000  9876.000000  9876.000000  9876.000000
# mean   24451.996760  55726.556341   416.248905     3.539287     0.168087
# std    14589.697248  32261.888225   553.066417     2.260945     0.203003
# min        2.000000   1040.000000     1.892000     1.000000     0.000000
# 25%    10949.750000  22801.000000    91.026000     2.000000     0.000000
# 50%    25100.500000  60505.000000   220.200000     3.000000     0.100000
# 75%    36579.500000  90032.000000   509.265000     5.000000     0.270000
# max    51284.000000  99301.000000  5759.964000    14.000000     0.850000
#
#             Profit  Shipping Cost
# count  9876.000000    9876.000000
# mean     28.878567      44.584919
# std     205.759936      72.560189
# min   -2750.280000       0.040000
# 25%     -12.175000       7.350000
# 50%      15.502200      20.225000
# 75%      69.360000      50.870000
# ...

# %%
tech=geet[geet["Category"]=="Technology"]
tech.describe()
# Out:
#              Row ID   Postal Code         Sales      Quantity      Discount  \
# count  10141.000000   1847.000000  10141.000000  10141.000000  10141.000000
# mean   25488.911449  55551.572279    467.858939      3.468691      0.135342
# std    14712.372594  31896.118284    708.972701      2.265671      0.199417
# min        8.000000   1841.000000      0.990000      1.000000      0.000000
# 25%    12873.000000  23392.000000    117.150000      2.000000      0.000000
# 50%    25340.000000  59601.000000    260.340000      3.000000      0.000000
# 75%    38091.000000  90008.000000    554.850000      5.000000      0.200000
# max    51287.000000  99207.000000  22638.480000     14.000000      0.700000
#
#              Profit  Shipping Cost
# count  10141.000000   10141.000000
# mean      65.454958      49.999876
# std      271.215376      79.022251
# min    -6599.978000       0.040000
# 25%        0.500000       9.560000
# 50%       29.940000      23.400000
# ...

# %%
office=geet[geet["Category"]=="Office Supplies"]
office.describe()
# Out:
#              Row ID   Postal Code         Sales      Quantity      Discount  \
# count  31273.000000   6026.000000  31273.000000  31273.000000  31273.000000
# mean   26073.185304  54890.951211    121.097120      3.459278      0.137409
# std    14883.181290  32046.665773    299.321405      2.288316      0.218518
# min        1.000000   1453.000000      0.444000      1.000000      0.000000
# 25%    13248.000000  23223.000000     20.340000      2.000000      0.000000
# 50%    25984.000000  55247.000000     46.380000      3.000000      0.000000
# 75%    39273.000000  90004.000000    105.240000      5.000000      0.200000
# max    51290.000000  99301.000000   9892.740000     14.000000      0.800000
#
#              Profit  Shipping Cost
# count  31273.000000   31273.000000
# mean      16.578961      12.964899
# std      109.749251      35.091158
# min    -3701.892800       0.000000
# 25%        0.450000       1.690000
# 50%        6.553800       4.250000
# ...

# %%
for z in x.columns:
    y=pd.isnull(x[z])
    if len(x[y])!=0:
        print(z,"Column contains missing values")
# Out:
# Postal Code Column contains missing values

# %%
duplicate = geet[geet.duplicated()]
print("there are {} duplicate rows in the file".format(len(duplicate)))
# Out:
# there are 0 duplicate rows in the file

# %%
x['Order Date']=pd.to_datetime(x['Order Date'])
x['Ship Date']=pd.to_datetime(x['Ship Date'])
# Out:
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\3808347708.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   x['Order Date']=pd.to_datetime(x['Order Date'])
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\3808347708.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   x['Ship Date']=pd.to_datetime(x['Ship Date'])

# %%
y=x.groupby("Category")
z=y["Sales"].sum()
plt.bar(z.keys(),z.values)
plt.xlabel("Category")
plt.ylabel("Sales")
plt.title("Sales by Category")
plt.show();

# %%
x["Region"].unique()
# Out:
# array(['East', 'Oceania', 'Central', 'Africa', 'West', 'South',
#        'Central Asia', 'EMEA', 'North Asia', 'North', 'Caribbean',
#        'Southeast Asia', 'Canada'], dtype=object)

# %%
pivottable=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Sales",columns="Category",aggfunc = np.sum)
pivottable
# Out:
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\2568691023.py:1: FutureWarning: The provided callable <function sum at 0x0000027445B4A660> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivottable=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Sales",columns="Category",aggfunc = np.sum)
# Category       Furniture  Office Supplies    Technology
# Order Date
# 2011        7.561924e+05     6.756065e+05  8.276521e+05
# 2012        8.589026e+05     7.950946e+05  1.023442e+06
# 2013        1.117724e+06     1.010718e+06  1.277305e+06
# 2014        1.378056e+06     1.305652e+06  1.616159e+06

# %%
pivottable.plot.bar()
plt.xlabel("Year")
plt.title("Sales by Category per year")
plt.show()

# %%
y=x.groupby("Category")
z=y["Quantity"].sum()
plt.bar(z.keys(),z.values)
plt.xlabel("Category")
plt.ylabel("Quantity")
plt.title("Quantity sold in each Category")
plt.show();

# %%
pivot_new_table=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Quantity",columns="Category",aggfunc = np.sum)
pivot_new_table
# Out:
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\3938039097.py:1: FutureWarning: The provided callable <function sum at 0x0000027445B4A660> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot_new_table=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Quantity",columns="Category",aggfunc = np.sum)
# Category    Furniture  Office Supplies  Technology
# Order Date
# 2011             6309            18976        6158
# 2012             7279            23135        7697
# 2013             9700            29147        9289
# 2014            11666            36924       12032

# %%
pivot_new_table.plot.bar()
plt.xlabel("Year")
plt.title("Quantity of each Category sold per year")
plt.show()

# %%
y=x.groupby("Region")
z=y["Profit"].sum()
new = pd.DataFrame.from_dict(z)
new['Profit']
new=new.sort_values('Profit',ascending=False)
new
# Out:
#                       Profit
# Region
# Central         311403.98164
# North           194597.95252
# North Asia      165578.42100
# South           140355.76618
# Central Asia    132480.18700
# Oceania         120089.11200
# West            108418.44890
# East             91522.78000
# Africa           88871.63100
# EMEA             43897.97100
# Caribbean        34571.32104
# Southeast Asia   17852.32900
# Canada           17817.39000

# %%
z.keys()
# Out:
# Index(['Africa', 'Canada', 'Caribbean', 'Central', 'Central Asia', 'EMEA',
#        'East', 'North', 'North Asia', 'Oceania', 'South', 'Southeast Asia',
#        'West'],
#       dtype='object', name='Region')

# %%
plt.bar(new.index,new['Profit'])
plt.xlabel("Region")
plt.ylabel("Profit")
plt.title("Profit in each Region")
plt.xticks(rotation=60)

plt.show();

# %%
x["Sub-Category"].unique()
# Out:
# array(['Accessories', 'Chairs', 'Phones', 'Copiers', 'Tables', 'Binders',
#        'Supplies', 'Appliances', 'Machines', 'Bookcases', 'Storage',
#        'Furnishings', 'Art', 'Paper', 'Envelopes', 'Fasteners', 'Labels'],
#       dtype=object)

# %%
pivot_new_2_table=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Profit",columns="Category",aggfunc = np.sum)
pivot_new_2_table
# Out:
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\3096998625.py:1: FutureWarning: The provided callable <function sum at 0x0000027445B4A660> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pivot_new_2_table=pd.pivot_table(x,index=pd.DatetimeIndex(geet['Order Date']).year,values="Profit",columns="Category",aggfunc = np.sum)
# Category     Furniture  Office Supplies    Technology
# Order Date
# 2011        53696.9264       85996.5343  109247.35084
# 2012        58132.8340      103305.5078  145976.93730
# 2013        84062.9005      149245.7358  173626.59388
# 2014        89312.0629      179926.0564  234927.85116

# %%
pivot_new_3_table=(pivot_new_2_table/pivottable)*100
pivot_new_3_table
# Out:
# Category    Furniture  Office Supplies  Technology
# Order Date
# 2011         7.100961        12.728791   13.199671
# 2012         6.768269        12.992857   14.263340
# 2013         7.520903        14.766314   13.593195
# 2014         6.481020        13.780557   14.536187

# %%
pivot_new_3_table.plot.bar()
plt.xlabel("Year")
plt.ylabel("Profit Margin(in percentage)")
plt.title("Profit Margin of each Category per year")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show();

# %%
pivot_new_2_table.plot.bar()
plt.xlabel("Year")
plt.ylabel("Profit ")
plt.title("Profit of each Category per year")
plt.legend(bbox_to_anchor=(1.05, 1.0), loc='upper left')
plt.show();

# %%
sns.set_style("whitegrid") 
sns.boxplot(x="Category",y="Profit",data=x,palette="Set1")
# Out:
# C:\Users\VIJAY ISRANI\AppData\Local\Temp\ipykernel_15636\564285299.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Category",y="Profit",data=x,palette="Set1")
# <Axes: xlabel='Category', ylabel='Profit'>

# %%
pair=x.drop(x.columns[0:15],axis=1)
pair=pair.drop(pair.columns[[1,2,5,7,8]],axis=1)
pair
# Out:
#               Category     Sales  Quantity    Profit
# 0           Technology  2309.650         7  762.1845
# 1            Furniture  3709.395         9 -288.7650
# 2           Technology  5175.171         9  919.9710
# 3           Technology  2892.510         5  -96.5400
# 4           Technology  2832.960         8  311.5200
# ...                ...       ...       ...       ...
# 51285  Office Supplies    65.100         5    4.5000
# 51286  Office Supplies     0.444         1   -1.1100
# 51287  Office Supplies    22.920         3   11.2308
# 51288  Office Supplies    13.440         2    2.4000
# 51289  Office Supplies    61.380         3    1.8000
#
# [51290 rows x 4 columns]

# %%
sns.pairplot(pair,hue="Category")
